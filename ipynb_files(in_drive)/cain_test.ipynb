# %%
# !git clone https://github.com/ssut/py-hanspell.git
# Out:
# Cloning into 'py-hanspell'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 101 (delta 5), reused 10 (delta 3), pack-reused 81
# Receiving objects: 100% (101/101), 25.27 KiB | 6.32 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# !pip3 install fire
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 87 kB 4.4 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=1ab00efe1a076488cc309ef170c5d267572259e86bc1d829083db90459078682
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
# %cd py-hanspell
# Out:
# /content/py-hanspell

# %%
# !python setup.py install
# Out:
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# creating py_hanspell.egg-info
# writing py_hanspell.egg-info/PKG-INFO
# writing dependency_links to py_hanspell.egg-info/dependency_links.txt
# writing requirements to py_hanspell.egg-info/requires.txt
# writing top-level names to py_hanspell.egg-info/top_level.txt
# writing manifest file 'py_hanspell.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'py_hanspell.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/hanspell
# copying hanspell/response.py -> build/lib/hanspell
# ...

# %%
import cv2
import re
import os
import tqdm
from PIL import Image
import pandas as pd
import numpy as np
import argparse
import time
#import pytesseract
#xfrom pytesseract import Output
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score
from google.colab import drive
#from hanspell import spell_checker
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
result = spell_checker.check(u' 재 미있는')
result = result.as_dict()  # dict로 출력

# %%
result['checked']
# Out:
# ' 재 이 있는'

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %%
# %cd /content
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Project/SW_Final
# Out:
# /content/drive/MyDrive/Project/SW_Final

# %%
# %cd /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark
# Out:
# /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark

# %%
CUDA_VISIBLE_DEVICES=0,1,2

# %%
# !python3 test.py --eval_data /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/test \
--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn --rgb --imgH 64 --imgW 150 --workers 0\
--saved_model /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy.pth
#81.5 acc
# Out:
# model input parameters 64 150 20 3 512 256 2353 25 TPS ResNet BiLSTM Attn
# loading pretrained model from /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy.pth
# dataset_root:    /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/test	 dataset: /
# sub-directory:	/.	 num samples: 3669

# %%
pred_df  = pd.read_csv('/content/drive/MyDrive/Project/SW_Final/open/result.csv',header=None)
save_df=pred_df
print(pred_df[0])
# Out:
# 0              도쿄
# 1             구카츠
# 2              바다
# 3              풍경
# 4           덕천중학교
#           ...
# 3664          배우는
# 3665    생활 보안 컷결음
# 3666          모바일
# 3667         클라우드
# 3668           보안
# Name: 0, Length: 3669, dtype: object

# %%
for i in tqdm(range(pred_df.shape[0])):
  result = spell_checker.check(pred_df[0][i])
  result = result.as_dict() 
  pred_df[0][i]=result['checked']
# Out:
#   0%|          | 0/3669 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b417b76f3102> in <module>
#       1 for i in tqdm(range(pred_df.shape[0])):
# ----> 2   result = spell_checker.check(pred_df[0][i])
#       3   result = result.as_dict()
# ...

# %%
best_acc = 81.5

# %%
# !ls

# %%
submit = pd.read_csv('/content/drive/MyDrive/Project/SW_Final/open/sample_submission.csv')
submit['text']= pred_df[0]
print(submit['text'])
# Out:
# 0              도쿄
# 1             구카츠
# 2              바다
# 3              풍경
# 4           덕천중학교
#           ...
# 3664          배우는
# 3665    생활 보안 컷결음
# 3666          모바일
# 3667         클라우드
# 3668           보안
# Name: text, Length: 3669, dtype: object

# %%
submit.to_csv('/content/drive/MyDrive/Project/SW_Final/open/'+str(best_acc)+'.csv', index=False, encoding="utf-8-sig")
