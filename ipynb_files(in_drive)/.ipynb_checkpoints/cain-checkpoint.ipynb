# %%
# !pip3 install fire
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 87 kB 2.1 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=1284d26f3ee498b4dbfddf5169789664bfa0387fd3f141ad07a4dc59f0c57b3d
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
import cv2
import re
import os
import tqdm
from PIL import Image
import pandas as pd
import numpy as np
import argparse
import time
#import pytesseract
#xfrom pytesseract import Output
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project/SW_Final
# Out:
# /content/drive/MyDrive/Project/SW_Final

# %%
# %cd deep-text-recognition-benchmark
# Out:
# /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark

# %%
# !ls
# Out:
# 'bigdata(3-1'		   LID-DS
#  Covid19_Prediction	  'Samsung_AI_Challenge(Materials Discovery)'
# 'Fraud_Detection(Dacon)'   SW_경진대회_예선
#  ICS_anomaly_detection	   SW_Final

# %%
CUDA_VISIBLE_DEVICES=0,1,2 #--workers 0

# %%
# !ls /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111
# Out:
# best_accuracy.pth  best_norm_ED.pth  log_dataset.txt  log_train.txt  opt.txt

# %%
# !python3 train.py --train_data /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/train --valid_data /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/validation \
	--Transformation TPS --FeatureExtraction ResNet --SequenceModeling BiLSTM --Prediction Attn \
	--batch_max_length 20 --workers 0 --imgH 64 --imgW 150 --num_iter 10000 --lr 0.1 --rgb --saved_model /content/drive/MyDrive/Project/SW_Final/deep-text-recognition-benchmark/saved_models/TPS-ResNet-BiLSTM-Attn-Seed1111/best_accuracy.pth 
	#79.630% pre-trained model train start
	#18
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 117151
# num total samples of /: 117151 x 1.0 (total_data_usage_ratio) = 117151
# num samples of / per batch: 192 x 1.0 (batch_ratio) = 192
# --------------------------------------------------------------------------------
# Total_batch_size: 192 = 192
# --------------------------------------------------------------------------------
# dataset_root:    /content/drive/MyDrive/Project/SW_Final/open/data_lmdb/validation	 dataset: /
# ...
